# %%
import pandas as pd

df_customers = pd.read_csv('data/customers.csv')
df_products = pd.read_csv('data/articles.csv')
df_transactions = pd.read_csv('data/transactions_train.csv')

df_customers.to_parquet('data/customers.parquet', index=False)
df_products.to_parquet('data/articles.parquet', index=False)
df_transactions.to_parquet('data/transactions_train.parquet', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 df_customers = pd.read_csv('data/customers.csv')
#       4 df_products = pd.read_csv('data/articles.csv')
#       5 df_transactions = pd.read_csv('data/transactions_train.csv')
#       6
#
# ...

# %%
from pathlib import Path
import pandas as pd

# Path.cwd() te da la ruta actual de Jupyter (seguramente acabe en .../analysis/utils)
# Con .parent subes a 'analysis', y con el segundo .parent subes a la raíz del proyecto
BASE_DIR = Path.cwd().parent.parent

# Ahora entramos en la carpeta data
DATA_DIR = BASE_DIR / 'data'

# Tus archivos
archivos_csv = ['articles.csv', 'customers.csv', 'transactions_train.csv']

print(f"Directorio base detectado: {BASE_DIR}")
print(f"Carpeta de datos detectada: {DATA_DIR}\n")
for archivo in archivos_csv:
    # 1. Al unir DATA_DIR (que es un Path) con archivo, ruta_csv se convierte en un objeto Path
    ruta_csv = DATA_DIR / archivo
    
    # 2. Ahora sí podemos usar .with_suffix() sobre ruta_csv
    ruta_parquet = ruta_csv.with_suffix('.parquet')
    
    if ruta_csv.exists():
        print(f"⏳ Leyendo: {archivo}...")
        df = pd.read_csv(ruta_csv)
        df.to_parquet(ruta_parquet, index=False, engine='pyarrow')
        print(f"✅ ¡Éxito! Guardado como: {ruta_parquet.name}\n")
    else:
        print(f"❌ Error: No se encontró el archivo en {ruta_csv}\n")
# Out:
# Directorio base detectado: c:\Users\jorge\OneDrive\Escritorio\Master\Big Data & Data Science\Proyecto Final
# Carpeta de datos detectada: c:\Users\jorge\OneDrive\Escritorio\Master\Big Data & Data Science\Proyecto Final\data
#
# ⏳ Leyendo: articles.csv...
# ✅ ¡Éxito! Guardado como: articles.parquet
#
# ⏳ Leyendo: customers.csv...
# ✅ ¡Éxito! Guardado como: customers.parquet
#
# ⏳ Leyendo: transactions_train.csv...
# ✅ ¡Éxito! Guardado como: transactions_train.parquet

# %%
# Copiamos y pegamos la ruta exacta del error (con la 'r' delante para que Windows lea bien las barras)
ruta_exacta = r"C:\Users\jorge\OneDrive\Escritorio\Master\Big Data & Data Science\Proyecto Final\HYM-Product-Recommende\data\customers.parquet"

print("Intentando leer directamente...")
df_prueba = pd.read_parquet(ruta_exacta)
print("¡Archivo leído con éxito! Tiene", len(df_prueba), "filas.")
# Out:
# Intentando leer directamente...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 # Copiamos y pegamos la ruta exacta del error (con la 'r' delante para que Windows lea bien las barras)
#       2 ruta_exacta = r"C:\Users\jorge\OneDrive\Escritorio\Master\Big Data & Data Science\Proyecto Final\HYM-Product-Recommende\data\customers.parquet"
#       3
#       4 print("Intentando leer directamente...")
# ----> 5 df_prueba = pd.read_parquet(ruta_exacta)
#       6 print("¡Archivo leído con éxito! Tiene", len(df_prueba), "filas.")
#
# File c:\Users\jorge\OneDrive\Escritorio\Master\Big Data & Data Science\Proyecto Final\ecommerce-marketing-ml\venv\Lib\site-packages\pandas\io\parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
# ...
